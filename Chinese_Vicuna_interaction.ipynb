# %% [markdown]
# <a href="https://colab.research.google.com/github/jack666000/webui_colab_all/blob/main/Chinese_Vicuna_interaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Facico/Chinese-Vicuna
# Out:
# Cloning into 'Chinese-Vicuna'...
# remote: Enumerating objects: 594, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 594 (delta 49), reused 54 (delta 20), pack-reused 494
# Receiving objects: 100% (594/594), 257.76 MiB | 27.03 MiB/s, done.
# Resolving deltas: 100% (313/313), done.

# %%
# !pip install -r ./Chinese-Vicuna/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-42x0k3p9
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-42x0k3p9
#   Resolved https://github.com/huggingface/transformers.git to commit c612628045822f909020f7eb6784c79700813eda
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/peft.git to /tmp/pip-req-build-2jikr9gx
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/peft.git /tmp/pip-req-build-2jikr9gx
#   Resolved https://github.com/huggingface/peft.git to commit e536616888d51b453ed354a6f1e243fecb02ea08
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %% [markdown]
# 如果你生成的网页信息被模型加载信息覆盖了，可以再跑一遍代码
#
# If the information on your generated page is overwritten by the model loading information, you can run the code again

# %%
# !python ./Chinese-Vicuna/interaction.py --lora_path Facico/Chinese-Vicuna-lora-7b-3epoch-belle-and-guanaco --use_local 0
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ...
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# ...
