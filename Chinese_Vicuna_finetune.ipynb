# %% [markdown]
# <a href="https://colab.research.google.com/github/jack666000/webui_colab_all/blob/main/Chinese_Vicuna_finetune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown "https://drive.google.com/uc?id=1tzXVhS74m-EtoFot7hEc005LDeZGPit_" -O merge.json
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tzXVhS74m-EtoFot7hEc005LDeZGPit_
# To: /content/merge.json
# 100% 696M/696M [00:05<00:00, 136MB/s]

# %%
# !git clone https://github.com/Facico/Chinese-Vicuna
# !pip install -r ./Chinese-Vicuna/requirements.txt
# Out:
# Cloning into 'Chinese-Vicuna'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 91 (delta 7), reused 3 (delta 1), pack-reused 70
# Unpacking objects: 100% (91/91), 59.76 MiB | 12.57 MiB/s, done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-bf4ixwxn
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-bf4ixwxn
#   Resolved https://github.com/huggingface/transformers.git to commit ff20f9cf3615a8638023bc82925573cb9d0f3560
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/peft.git to /tmp/pip-req-build-j6o6lpl2
# ...

# %%
# !python ./Chinese-Vicuna/finetune.py --data_path merge.json --test_size 2000
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ...
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# ...
